# %% [markdown]
# <a href="https://colab.research.google.com/github/Camillabgarcia/ML_Regressao_Linear/blob/main/Precificando_valor_de_vendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
